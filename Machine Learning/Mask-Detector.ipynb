# %% [markdown]
# # 1. Install Libraries

# %%
pip install -r '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection/requirements-gpu.txt'

# %% [markdown]
# # 2. Import and Check TF

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0-rc0

# %% [markdown]
# # 3. Change to Detection Directory

# %%
# %cd /content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection
# Out:
# /content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection

# %% [markdown]
# # 4. Convert YoloV4 Weights to TF Model

# %%
# !python save_model.py --weights '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/training/yolov4-custom_best.weights' --output '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection/TFmodel' --input_size 416 --model yolov4

# %%
# !python save_model.py --framework tflite --weights '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/training/yolov4-custom_best.weights' --output '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection/TF_Model' --input_size 416 --model yolov4
# Out:
# 2021-05-31 12:56:56.665212: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-31 12:56:58.215310: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-05-31 12:56:58.237072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-31 12:56:58.237874: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-05-31 12:56:58.237916: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# # 5. Detect Face Mask in Video

# %%
# !python detect_video.py --weights '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection/TFmodel' --size 416 --model yolov4 --video '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/video test/Wearing a face mask in scared of coronavirus in the Philippines.mp4' --output '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/video test/RESULT WITH INFO - Wearing a face mask in scared of coronavirus in the Philippines.mp4' --count
# Out:
# 2021-05-24 12:54:24.656564: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 12:54:25.903462: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-05-24 12:54:25.906701: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-05-24 12:54:25.906745: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: 4f80a2a4a056
# 2021-05-24 12:54:25.906760: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: 4f80a2a4a056
# 2021-05-24 12:54:25.906861: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# 2021-05-24 12:54:25.906903: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.32.3
# ...

# %% [markdown]
# # 6. Convert TF Model to Pickle File

# %%
# %cd /content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection

import pickle

with open('mask_detector_pickle.pkl', 'wb') as r:
  pickle.dump('/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection/TF_Model/saved_model.pb', r)
# Out:
# /content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection

# %% [markdown]
# # 7. Convert TF Model to TFLite

# %%
# %cd /content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection

# !python convert_tflite.py --weights '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection/TF_Model' --output '/content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection/TFLite_Model.tflite'
# Out:
# /content/drive/MyDrive/Machine Learning/Mask Detector YOLOV4/detection
# 2021-05-31 15:04:44.975146: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-31 15:04:49.317856: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-05-31 15:04:49.376674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-31 15:04:49.377477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...
